# %%
# Import all essential libraries

import os
import csv
import math
import warnings
import random as r
import numpy as np
import networkx as nx
import scipy.constants as sc
import matplotlib.pyplot as plt
import networkx.algorithms.isomorphism as iso

# %%
class Compound():
    def __init__(self, name, number):
        self._name = name + " " + str(number)
        self._number = number
        self._valency = self.get_max_valency()

    def get_max_valency(self):
        name = self._name.split()[0]
        if name == "H":
            return 1
        elif name == "C":
            return 4
        elif name == "N":
            return 3
        elif name == "O":
            return 2
        elif name == "S":
            return 2

    def current_valency(self, G):
        neig = nx.degree(G, self)
        max_val = self.get_max_valency()
        if neig > max_val:
            raise ValueError('Compound has more neighbours than valence')
        else:
            # print(max_val, neig)
            self._valency = max_val - neig
        
    def get_total_valency(self, G):
        neig = nx.degree(G, self)
        free_electrons = self.get_max_valency() - neig
        return free_electrons
        
        
    def __repr__(self):
        return self._name

# %%
def plot_fig(G):
    A = nx.adjacency_matrix(G)
    pos = nx.spring_layout(G)
    nodes = list(nx.nodes(G))
    mapping = {}
    for i,j in enumerate(nodes):
        mapping[j] = i
        
    plt.figure()
    for i in G.edges():
        G[i[0]][i[1]][0]['number'] = A[mapping[i[0]], mapping[i[1]]]
    labels = nx.get_edge_attributes(G, 'number')
    edge_labels = {}
    for i in labels:
        edge_labels[(i[0], i[1])] = labels[i]
    nx.draw(G, pos, with_labels=True,edge_color='black',width=1,linewidths=1,node_size = 500,node_color='pink',alpha=0.9)
    nx.draw_networkx_edge_labels(G, pos, edge_labels = edge_labels)
    plt.axis('off')
    plt.show()

# %%
# Defining the atom list in the Graph

H_list = [Compound("H", i) for i in range(1,33)]
C_list = [Compound("C", i) for i in range(33, 41)]
O_list = [Compound("O", i) for i in range(41, 49)]
N_list = [Compound("N", i) for i in range(49, 57)]

complete_list = [];
for lst in [H_list, C_list, O_list, N_list]:
    complete_list.extend(lst)

# %%
# Creating the graph with just atoms
# MultiGraph is being used for ease of representing
# double and possible triple bonds
# Here, 
#    - lst loops through the lists (H, C, O and N)
#    - comp loops over the compounds

G = nx.MultiGraph()
for i,lst in enumerate([H_list, C_list, O_list, N_list]):
    for comp in lst:
        G.add_node(comp, data=comp)
plot_fig(G)

# %%
nx.nodes(G)
# Out:
# NodeView((H 1, H 2, H 3, H 4, H 5, H 6, H 7, H 8, H 9, H 10, H 11, H 12, H 13, H 14, H 15, H 16, H 17, H 18, H 19, H 20, H 21, H 22, H 23, H 24, H 25, H 26, H 27, H 28, H 29, H 30, H 31, H 32, C 33, C 34, C 35, C 36, C 37, C 38, C 39, C 40, O 41, O 42, O 43, O 44, O 45, O 46, O 47, O 48, N 49, N 50, N 51, N 52, N 53, N 54, N 55, N 56))

# %%
# Function to update the valencies of the atoms
# This function updates the atom valencies based 
# on the number of edges that atom forms.

def fix_valencies(G):
    for node in nx.nodes(G):
        degree = len(G[node])
        if degree > 0:
            node.current_valency(G)

# %%
# Adding all the nodes

G.add_edges_from([(H_list[0], N_list[0]), (N_list[0], H_list[1]), (N_list[0], H_list[2])])
G.add_edges_from([(H_list[3], N_list[1]), (N_list[1], H_list[4]), (N_list[1], H_list[5])])

G.add_edges_from([(H_list[6], C_list[0]), (H_list[7], C_list[0]), (H_list[8], C_list[0]), (H_list[9], C_list[0])])
G.add_edges_from([(H_list[10], C_list[1]), (H_list[11], C_list[1]), (H_list[12], C_list[1]), (H_list[13], C_list[1])])

#Added CH3, CH2 and OH to test bond formations. Can be erased later.
G.add_edges_from([(H_list[14], C_list[2]), (H_list[15], C_list[2]), (H_list[16], C_list[2])])
G.add_edges_from([(H_list[17], C_list[3]), (H_list[18], C_list[3])])
G.add_edge(O_list[6], H_list[28])

fix_valencies(G)
for i in G.nodes:
    print(i._name, i._valency)

plot_fig(G)
# Out:
# H 1 0
# H 2 0
# H 3 0
# H 4 0
# H 5 0
# H 6 0
# H 7 0
# H 8 0
# H 9 0
# H 10 0
# H 11 0
# H 12 0
# H 13 0
# H 14 0
# H 15 0
# H 16 0
# H 17 0
# H 18 0
# H 19 0
# H 20 1
# H 21 1
# H 22 1
# H 23 1
# H 24 1
# H 25 1
# H 26 1
# H 27 1
# H 28 1
# H 29 0
# H 30 1
# H 31 1
# H 32 1
# C 33 0
# C 34 0
# C 35 1
# C 36 2
# C 37 4
# C 38 4
# C 39 4
# C 40 4
# O 41 2
# O 42 2
# O 43 2
# O 44 2
# O 45 2
# O 46 2
# O 47 1
# O 48 2
# N 49 0
# N 50 0
# N 51 3
# N 52 3
# N 53 3
# N 54 3
# N 55 3
# N 56 3

# %%
nx.nodes(G)
# Out:
# NodeView((H 1, H 2, H 3, H 4, H 5, H 6, H 7, H 8, H 9, H 10, H 11, H 12, H 13, H 14, H 15, H 16, H 17, H 18, H 19, H 20, H 21, H 22, H 23, H 24, H 25, H 26, H 27, H 28, H 29, H 30, H 31, H 32, C 33, C 34, C 35, C 36, C 37, C 38, C 39, C 40, O 41, O 42, O 43, O 44, O 45, O 46, O 47, O 48, N 49, N 50, N 51, N 52, N 53, N 54, N 55, N 56))

# %%
# Function to calculate H

def calculate_H(data, T):
    [a_2, a_1, a0, a1, a2, a3, a4, a5, _] = data

    H = sc.R*T*(-a_2*T**-2 + a_1*T**-1*np.log(T) + a0 + 0.5*a1*T + (a2*T**2)/3 + 0.25*a3*T**3 + 0.2*a4*T**4 +a5*T**-1)
    return H

# Function to calculate S

def calculate_S(data, T):
    [a_2, a_1, a0, a1, a2, a3, a4, _, a6] = data

    S = sc.R*(-0.5*a_2*T**-2 - a_1*T**-1 + a0*np.log(T) + a1*T + 0.5*a2*T**2 + (a3*T**3/3) + 0.25*a4*T**4 + a6)

    return S

# Function to calculate G

def calculate_G(H, S, T):
    G = H - T*S
    return G

# %%
# Code to get the H, S and G data for a whole dataset

def get_lib_data(libraries_list, temperature, path):
    # libraries_list = rmg_link_lists()

    H_lists = []
    S_lists = []
    G_lists = []

    H_list = []
    S_list = []
    G_list = []

    for lib in libraries_list:
        os.chdir(path)

        compound_list = os.listdir()        

        directory = f"{lib}_data"
        if os.path.exists(f"{directory}/csv"):
            print("CSV folder exists")
            os.chdir(f"{directory}/csv")
        
            compound_list = os.listdir()

            for file_name in compound_list:
                fin = open(file_name)
                reader = csv.reader(fin)
                data = []
                if (temperature > 100 and temperature < 1074.56):
                    for i in reader:
                        data.append(float(i[0]))
                else:
                    for i in reader:
                        data.append(float(i[1]))

                H = calculate_H(data, temperature)
                S = calculate_S(data, temperature)
                G = calculate_G(S, H, temperature)

                H_list.append(H)
                S_list.append(S)
                G_list.append(G)

            H_lists.append(H_list)
            S_lists.append(S_list)
            G_lists.append(G_list)

    return [H_lists, S_lists, G_lists]

# path = os.getcwd()
# libraries_list = ['primaryThermoLibrary', 'DFT_QCI_thermo', 'GRI-Mech3.0', 'CBS_QB3_1dHR', 'thermo_DFT_CCSDTF12_BAC', 'SABIC_aromatics', 'C3', 'Fulvene_H', 'BurkeH2O2', 'Chlorinated_Hydrocarbons', 'Narayanaswamy', 'CHN', 'surfaceThermoPt', 'vinylCPD_H', 'SulfurGlarborgH2S', 'naphthalene_H', 'NOx2018', 'iodinated_Hydrocarbons', 'JetSurF1.0', 'surfaceThermoNi', 'SulfurGlarborgMarshall', 'CH', 'NitrogenCurran', 'CHO', 'bio_oil', 'SulfurLibrary', 'C10H11', 'Klippenstein_Glarborg2016', 'primaryNS', 'CurranPentane', 'USC-Mech-ii', 'GRI-Mech3.0-N', 'JetSurF2.0', 'FFCM1(-)', 'SulfurGlarborgNS', 'NISTThermoLibrary', 'Lai_Hexylbenzene', 'SulfurHaynes', 'CN', 'BurcatNS', 'SulfurGlarborgBozzelli', 'Chernov', 'CHON']

# [H_lists, S_lists, G_lists] = get_lib_data(libraries_list, 700, path)

# for lib,H_list,S_list,G_list in zip(libraries_list, H_lists, S_lists, G_lists):
#     print(lib)

#     for H, S, G in zip(H_list, S_list, G_list):
#         print("%.2f" %H, end="\t\t")
#         print("%.2f" %S, end="\t\t")
#         print("%.2f" %G)

# %%
# Code to calculate the H, S and G values for specific compound
def get_single_compound_data(lib, temperature, path, file_name):
    # Code to calculate the H, S and G values for specific compound
    os.chdir(path) 

    directory = f"{lib}_data"    
    if os.path.exists(f"{directory}/csv"):
        os.chdir(f"{directory}/csv")
        
        fin = open(file_name)
        reader = csv.reader(fin)
        data1 = []
        data2 = []

        for row in reader:
            data1.append(float(row[0]))
            data2.append(float(row[1]))
            
        if (temperature > data1[0] and temperature < data1[1]):
            # print('Choosing from data 1')
            data = data1[2:]
        elif (temperature > data2[0] and temperature < data2[1]):
            # print('Choosing from data 2')
            data = data2[2:]
        else:
            print("The enquired compound doesn't have data for the temperature provided.")

        H = calculate_H(data, temperature)
        S = calculate_S(data, temperature)
        G = calculate_G(H, S, temperature)
        
        os.chdir(path)
        return (H, S, G)
    else:
        print("The file requested is unavailable")

# %%
# A test example for calculating G

temperature = 700
path = os.getcwd()

# Details for NH3 (Ammonia)
# https://rmg.mit.edu/database/thermo/molecule/1%20N%20u0%20p1%20c0%20%7B2,S%7D%20%7B3,S%7D%20%7B4,S%7D%0A2%20H%20u0%20p0%20c0%20%7B1,S%7D%0A3%20H%20u0%20p0%20c0%20%7B1,S%7D%0A4%20H%20u0%20p0%20c0%20%7B1,S%7D%0A
ammonia_lib = "NOx2018"
ammonia_file_name = "65.csv"

os.chdir(path)
result = get_single_compound_data(ammonia_lib, temperature, path, ammonia_file_name)
print(result)
# Out:
# (-28703.85868409499, 227.77781807246183, -188148.33133481827)

# %%
# Get the list of all components and atoms

atoms = []
compounds = []
all_compounds = nx.connected_components(G)
list_compounds = list(all_compounds)

for i in range(len(list_compounds)):
    if len(list(list_compounds[i])) == 1:
        atoms.append(list(list_compounds[i])[0])
    else:
        compounds.append(list(list_compounds[i]))

# %%
free_electrons = []
for i in complete_list:
    val = 0
    compound_contrib = {}
    if np.size(i) > 1:
        for j in i:
            compound_contrib[j] = j.get_total_valency(G)
            val += j.get_total_valency(G)
    else:
        compound_contrib[i] = i.get_total_valency(G)
        val += i.get_total_valency(G)
    free_electrons.append((val, compound_contrib))

# %%
maximum_edges = 0; # 52
for lst in [H_list, C_list, O_list, N_list]:
    for atom in lst:
        maximum_edges += atom.get_max_valency()
        
maximum_edges = maximum_edges//2;
print(maximum_edges)
# Out:
# 52

# %%
# G = generate_random_graphs(G, maximum_edges)
# nx.draw(G, with_labels=True)
# plt.show()
# print(nx.number_of_edges(G))

# %%
H = nx.MultiGraph()

H_lists = [Compound("H",i) for i in range(1,17)]
C_lists = [Compound("C",i) for i in range(17, 21)]
O_lists = [Compound("O",i) for i in range(21, 24)]
N_lists = [Compound("N",i) for i in range(24, 26)]
for i,lst in enumerate([H_lists, C_lists, O_lists, N_lists]):
    for comp in lst:
        H.add_node(comp, data=comp)

# nx.draw(H,with_labels=True)
H.add_edges_from([(H_lists[0], N_lists[0]), (N_lists[0], H_lists[1]), (N_lists[0], H_lists[2])])
H.add_edges_from([(H_lists[3],C_lists[0]), (H_lists[4],C_lists[0]), (H_lists[5],C_lists[0]), (H_lists[6],C_lists[0])])
H.add_edges_from([(H_lists[7],C_lists[1]), (H_lists[8],C_lists[1]), (H_lists[9],C_lists[1])])
H.add_edges_from([(H_lists[10],C_lists[2]), (H_lists[11],C_lists[2])])
H.add_edges_from([(H_lists[12],O_lists[0]), (H_lists[13],O_lists[0])])
H.add_edges_from([(H_lists[14],O_lists[1])])

plot_fig(H)

data_G = {}
G_value = [-185940.2151,-212885.1171,2651.927862,247769.9191,-380604.1595,-2327000,133624.1442,736592.6058,316500,361063.4601]

entities = nx.connected_components(H)
entities = list(entities)
for i in range(len(entities)):
    sub = H.subgraph(list(entities[i]))
    # print(sub.edges)
    data_G[sub] = G_value[i]
    
print(data_G)
# Out:
# {<networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015610>: -185940.2151, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015c10>: -212885.1171, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015370>: 2651.927862, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015640>: 247769.9191, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015400>: -380604.1595, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa30154c0>: -2327000, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa30152e0>: 133624.1442, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015f40>: 736592.6058, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015ee0>: 316500, <networkx.classes.multigraph.MultiGraph object at 0x7f6aa3015df0>: 361063.4601}

# %%
plot_fig(G)
for i in G.nodes:
    i.current_valency(G)
    print(i._name, i._valency)
# Out:
# H 1 0
# H 2 0
# H 3 0
# H 4 0
# H 5 0
# H 6 0
# H 7 0
# H 8 0
# H 9 0
# H 10 0
# H 11 0
# H 12 0
# H 13 0
# H 14 0
# H 15 0
# H 16 0
# H 17 0
# H 18 0
# H 19 0
# H 20 1
# H 21 1
# H 22 1
# H 23 1
# H 24 1
# H 25 1
# H 26 1
# H 27 1
# H 28 1
# H 29 0
# H 30 1
# H 31 1
# H 32 1
# C 33 0
# C 34 0
# C 35 1
# C 36 2
# C 37 4
# C 38 4
# C 39 4
# C 40 4
# O 41 2
# O 42 2
# O 43 2
# O 44 2
# O 45 2
# O 46 2
# O 47 1
# O 48 2
# N 49 0
# N 50 0
# N 51 3
# N 52 3
# N 53 3
# N 54 3
# N 55 3
# N 56 3

# %%
# Finding G of all components given a network
def input_G(G):
    
    cc = list(nx.connected_components(G))
    G_energy = 0
    
    for i in range(len(cc)):
        found = 0
        
        # print("Connected Component G:", cc[i])
        sub_G = G.subgraph(list(cc[i]))
        same = False
        
        for j in data_G:
            # print(j.nodes)
            GH = iso.GraphMatcher(sub_G,j)
            
            # print("Isomorphic:", GH.is_isomorphic())
            if GH.is_isomorphic() == True:
                same = True
            else:
                same = False
            
            if same == True:
                if len(GH.mapping) != 2:
                    for k in GH.mapping: # check mapping of each nodes
                        # print(str(k)[0])
                        # print(str(GH.mapping[k])[0])
                        if str(k)[0] == str(GH.mapping[k])[0]: # Each node's label (without index) should coincide
                            same = True
                        else:
                            same = False
                            break
                else:
                    keys = []
                    values = []
                    for i in GH.mapping.keys():
                        keys.append(str(i).split()[0])
                    for i in GH.mapping.keys():
                        values.append(str(i).split()[0])
                    keys = keys.sort()
                    values = values.sort()
                    if keys == values:
                        same = True
                    else: 
                        same = False
                        
                # print(same)
                
            if same == True: # If compound is found, add G
                found = 1
                break

        if same == True:
            G_energy += data_G[j]
            
        elif same == False: # If compound not found,
            randomp = G.subgraph(list(cc[i]))
            plot_fig(randomp)
            
            val = float(input('Enter G value of %s: '%list(cc[i])))
            data_G[sub_G] = val # Add the new compound's data to our dictionary
            G_energy += val
            # print(G_energy)
    return G_energy

# %%
input_G(G)
# Out:
# 6057512.096761999

# %%
plot_fig(G)
cc = nx.connected_components(G)
for i in cc:
    if len(i) > 1:
        M = G.subgraph(list(i))
        plot_fig(M)

# %%
def get_exp_number_bonds(s, max_bonds):
    # Function imitates a Michaelis-Menten curve
    # for the number of bonds allowable at a 
    # given cycle and ceils the value returned.
    bond = math.ceil((max_bonds*s)/(0.5 + s))
    
    return bond

# %%
def generate_random_graphs_new(G, max_bonds, probab):
    nodes = list(nx.nodes(G))
    print("Length:", len(nodes))
    connected_components = nx.connected_components(G)
    for i in connected_components:
        if len(i) > 1:
            plot_fig(G.subgraph(list(i)))
        
    A = nx.adjacency_matrix(G)

    bonds = get_exp_number_bonds(probab, max_bonds)
    print("Bonds to be formed:", bonds)
    print("Number of edges:", nx.number_of_edges(G))
    if bonds > max_bonds:
        bonds = 0

    while nx.number_of_edges(G) < bonds:
        print("Bonds to be formed:", bonds)
        print("Number of edges:", nx.number_of_edges(G))
        flag = 0
        row = r.randint(1,len(nodes)-1)
        cur_val1 = (nodes[row])._valency
        
        while not(cur_val1 >= 1):
            flag = 1
            row = r.randint(0,len(nodes)-1)
            cur_val1 = nodes[row]._valency
        else:
            print("Node1:", nodes[row]._name)
            print("Curr val1:", cur_val1)
            col = r.randint(0, row-1)
            cur_val2 = nodes[col]._valency
            print("flag:", flag)
            while (not(cur_val2 >= 1)) or (row==col):
                flag = 2
                col = r.randint(0, len(nodes)-1)
                cur_val2 = nodes[col]._valency
                print("Random node choosen:", nodes[col]._name)
                if cur_val2 > 0:
                    max_num_edges = r.randint(1, min(nodes[row]._valency, nodes[col]._valency))
                    print("Node2:", nodes[col]._name)
                    print("Curr val2:", cur_val2)
                    print(nodes[row]._valency, nodes[col]._valency)
                    print("max_num_edges:", max_num_edges)
                    
                    for cc in nx.connected_components(G):
                        if nodes[row] in cc:
                            plot_fig(G.subgraph(list(cc)))
                        if nodes[col] in cc:
                            plot_fig(G.subgraph(list(cc)))
                            
                    for times in range(max_num_edges):
                        G.add_edge(nodes[row], nodes[col])
            print("flag_end:", flag)
            if flag == 0 and (row!= col):
                print(nodes[row]._name, nodes[row]._valency)
                print(nodes[col]._name, nodes[col]._valency)
                if min(nodes[row]._valency, nodes[col]._valency) > 1:
                    max_num_edges = r.randint(1, min(nodes[row]._valency, nodes[col]._valency))
                else: max_num_edges = 1
                print("max_num_edges:", max_num_edges)
                for times in range(max_num_edges):
                    G.add_edge(nodes[row], nodes[col])

        for i in list(nx.nodes(G)):
            if (i==nodes[row]) or (i==nodes[col]): 
                print(i._name, "Previous Valency:", i._valency)
            try:
                i.current_valency(G)
            except ValueError:
                print(i._name)
                print(i._valency)
                print("ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                for cc in nx.connected_components(G):
                    if nodes[row] in cc:
                        plot_fig(G.subgraph(list(cc)))
            if (i==nodes[row]) or (i==nodes[col]): 
                print(i._name, "Current valency:", i._valency)
    return G

# %%
A_list = H_list[0:5]
B_list = C_list[0:5]
Z_list = O_list[0:5]
Y_list = N_list[0:5]

M = nx.MultiGraph()
for i,lst in enumerate([A_list, B_list, Z_list, Y_list]):
    for comp in lst:
        M.add_node(comp, data=comp)

generate_random_graphs_new(M, 10, 2)
for i in nx.connected_components(M):
    if len(i) > 1:
        plot_fig(M.subgraph(list(i)))
# Out:
# Length: 20
# Bonds to be formed: 8
# Number of edges: 0
# Bonds to be formed: 8
# Number of edges: 0
# Node1: C 37
# Curr val1: 4
# flag: 0
# Random node choosen: C 35
# Node2: C 35
# Curr val2: 3
# 4 3
# max_num_edges: 3
# flag_end: 2
# C 35 Previous Valency: 3
# C 35 Current valency: 1
# C 37 Previous Valency: 4
# C 37 Current valency: 1
# Bonds to be formed: 8
# Number of edges: 3
# Node1: N 49
# Curr val1: 3
# flag: 0
# flag_end: 0
# N 49 3
# C 33 4
# max_num_edges: 3
# C 33 Previous Valency: 4
# C 33 Current valency: 1
# N 49 Previous Valency: 3
# N 49 Current valency: 0
# Bonds to be formed: 8
# Number of edges: 6
# Node1: H 5
# Curr val1: 1
# flag: 0
# flag_end: 0
# H 5 1
# H 4 1
# max_num_edges: 1
# H 4 Previous Valency: 1
# H 4 Current valency: 0
# H 5 Previous Valency: 1
# H 5 Current valency: 0
# Bonds to be formed: 8
# Number of edges: 7
# Node1: N 52
# Curr val1: 3
# flag: 0
# flag_end: 0
# N 52 3
# C 34 4
# max_num_edges: 1
# C 34 Previous Valency: 4
# C 34 Current valency: 3
# N 52 Previous Valency: 3
# N 52 Current valency: 2

# %%
#Simulated Annealing

# Variables -
# Gi_1 = calculated G of initial compound 1
# Gi_2 = calculated G of initial compound 2
# Gf = calculated G of final compound if edge formation occurs.
# Number of cycles
# Number of trials per cycle
# Number of accepted solutions
# Probability of accepting worse solution at the start
# Probability of accepting worse solution at the end
# Initial temperature
# Final temperature
# Fractional reduction every cycle
# Generate new trial points
# iterate over the list of connected components and find a new trial compound that can be combined - find 2.
# Initialize DeltaE_avg if a worse solution was found
#   on the first iteration
# objective function is worse
# generate probability of acceptance
# determine whether to accept worse point

def simulated_annealing(G):
    
    num_cycles = 50
    num_trails = 10
    num_acc = 0.0
    
    p_initial = 0.7
    p_final = 0.001
    
    t_initial = -1.0/math.log(p_initial)
    t_final = -1.0/math.log(p_final)
    frac = (t_final/t_initial)**(1.0/(num_cycles-1.0))
    
    t = t_initial
    for i in range(num_cycles):
        
        # Finding Ginitial (Gi) based on initial set up of the network
        Gi = input_G(G)
        initial_network = G
        
        print('Cycle: ' + str(i) + ' with Temperature: ' + str(t))
        print('Gi = %f'%Gi)
        for j in range(num_trails):
            probab = (i+1)*num_trails + (j+1)
            print("probab:", probab)
            # Generating random graphs and taking input for Gfinal (Gf)   
            G = generate_random_graphs_new(G, maximum_edges, probab)
            Gf = input_G(G)
            print('Gf = %f'%Gf)
            initial_diff_G = Gf - Gi
            if (i==0 and j==0):
                diff_G = initial_diff_G
            print(diff_G)
            
            if (initial_diff_G > 0):
                p = math.exp(-initial_diff_G/(diff_G * t))
                if (r.random() < p):
                    accept_bad = True
                else:
                    accept_bad = False
            else:
                # objective function is lower, automatically accept_bad
                accept_bad = True
            print(accept_bad)
            if (accept_bad == True):
                # create an edge between the 2 elements. (should satisfy valency and that should be checked earlier)
                # increment number of accepted solutions
                num_acc = num_acc + 1.0
                # update DeltaE_avg
                diff_G = (diff_G*(num_acc-1.0) +  initial_diff_G) / num_acc
            if (accept_bad == False):
                G = initial_network
        # Record the lowest G values at the end of every cycle (this was a part of the original code. we need not do this)
        # Lower the temperature for next cycle
        t = frac*t
    return G

# %%
for i in G.nodes:
    i.current_valency(G)
    print(i._name, i._valency)
# Out:
# H 1 0
# H 2 0
# H 3 0
# H 4 0
# H 5 0
# H 6 0
# H 7 0
# H 8 0
# H 9 0
# H 10 0
# H 11 0
# H 12 0
# H 13 0
# H 14 0
# H 15 0
# H 16 0
# H 17 0
# H 18 0
# H 19 0
# H 20 1
# H 21 1
# H 22 1
# H 23 1
# H 24 1
# H 25 1
# H 26 1
# H 27 1
# H 28 1
# H 29 0
# H 30 1
# H 31 1
# H 32 1
# C 33 0
# C 34 0
# C 35 1
# C 36 2
# C 37 4
# C 38 4
# C 39 4
# C 40 4
# O 41 2
# O 42 2
# O 43 2
# O 44 2
# O 45 2
# O 46 2
# O 47 1
# O 48 2
# N 49 0
# N 50 0
# N 51 3
# N 52 3
# N 53 3
# N 54 3
# N 55 3
# N 56 3

# %%
V = simulated_annealing(G)
# Out:
# Cycle: 0 with Temperature: 2.8036732520571284
# Gi = 6057512.096762
# probab: 11
# Length: 56
# Bonds to be formed: 50
# Number of edges: 20
# Bonds to be formed: 50
# Number of edges: 20
# Node1: C 36
# Curr val1: 2
# flag: 0
# Random node choosen: H 2
# Random node choosen: H 11
# Random node choosen: H 23
# Node2: H 23
# Curr val2: 1
# 2 1
# max_num_edges: 1
# flag_end: 2
# H 23 Previous Valency: 1
# H 23 Current valency: 0
# C 36 Previous Valency: 2
# C 36 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 21
# Node1: N 51
# Curr val1: 3
# flag: 0
# Random node choosen: N 49
# Random node choosen: H 19
# Random node choosen: N 55
# Node2: N 55
# Curr val2: 3
# 3 3
# max_num_edges: 3
# flag_end: 2
# N 51 Previous Valency: 3
# N 51 Current valency: 0
# N 55 Previous Valency: 3
# N 55 Current valency: 0
# Bonds to be formed: 50
# Number of edges: 24
# Node1: C 38
# Curr val1: 4
# flag: 0
# Random node choosen: N 49
# Random node choosen: N 52
# Node2: N 52
# Curr val2: 3
# 4 3
# max_num_edges: 3
# flag_end: 2
# C 38 Previous Valency: 4
# C 38 Current valency: 1
# N 52 Previous Valency: 3
# N 52 Current valency: 0
# Bonds to be formed: 50
# Number of edges: 27
# Node1: H 26
# Curr val1: 1
# flag: 1
# Random node choosen: C 38
# Node2: C 38
# Curr val2: 1
# 1 1
# max_num_edges: 1
# flag_end: 2
# H 26 Previous Valency: 1
# H 26 Current valency: 0
# C 38 Previous Valency: 1
# C 38 Current valency: 0
# Bonds to be formed: 50
# Number of edges: 28
# Node1: H 30
# Curr val1: 1
# flag: 0
# Random node choosen: H 18
# Random node choosen: O 45
# Node2: O 45
# Curr val2: 2
# 1 2
# max_num_edges: 1
# flag_end: 2
# H 30 Previous Valency: 1
# H 30 Current valency: 0
# O 45 Previous Valency: 2
# O 45 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 29
# Node1: H 24
# Curr val1: 1
# flag: 0
# Random node choosen: H 19
# Random node choosen: O 46
# Node2: O 46
# Curr val2: 2
# 1 2
# max_num_edges: 1
# flag_end: 2
# H 24 Previous Valency: 1
# H 24 Current valency: 0
# O 46 Previous Valency: 2
# O 46 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 30
# Node1: H 20
# Curr val1: 1
# flag: 0
# Random node choosen: C 34
# Random node choosen: H 20
# Node2: H 20
# Curr val2: 1
# 1 1
# max_num_edges: 1
# Random node choosen: H 32
# Node2: H 32
# Curr val2: 1
# 1 1
# max_num_edges: 1
# flag_end: 2
# H 20 Previous Valency: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 20 Current valency: 1
# H 32 Previous Valency: 1
# H 32 Current valency: 0
# Bonds to be formed: 50
# Number of edges: 32
# Node1: O 48
# Curr val1: 2
# flag: 0
# flag_end: 0
# O 48 2
# O 44 2
# max_num_edges: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 44 Previous Valency: 2
# O 44 Current valency: 1
# O 48 Previous Valency: 2
# O 48 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 33
# Node1: N 54
# Curr val1: 3
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 46 Previous Valency: 1
# O 46 Current valency: 1
# N 54 Previous Valency: 3
# N 54 Current valency: 3
# Bonds to be formed: 50
# Number of edges: 33
# Node1: C 39
# Curr val1: 4
# flag: 1
# Random node choosen: N 51
# Random node choosen: H 21
# Node2: H 21
# Curr val2: 1
# 4 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 21 Previous Valency: 1
# H 21 Current valency: 0
# C 39 Previous Valency: 4
# C 39 Current valency: 3
# Bonds to be formed: 50
# Number of edges: 34
# Node1: N 54
# Curr val1: 3
# flag: 0
# Random node choosen: H 8
# Random node choosen: H 28
# Node2: H 28
# Curr val2: 1
# 3 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 28 Previous Valency: 1
# H 28 Current valency: 0
# N 54 Previous Valency: 3
# N 54 Current valency: 2
# Bonds to be formed: 50
# Number of edges: 35
# Node1: C 37
# Curr val1: 4
# flag: 0
# Random node choosen: C 36
# Node2: C 36
# Curr val2: 1
# 4 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# C 36 Previous Valency: 1
# C 36 Current valency: 0
# C 37 Previous Valency: 4
# C 37 Current valency: 3
# Bonds to be formed: 50
# Number of edges: 36
# Node1: O 45
# Curr val1: 1
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 43 Previous Valency: 2
# O 43 Current valency: 2
# O 45 Previous Valency: 1
# O 45 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 36
# Node1: O 42
# Curr val1: 2
# flag: 1
# Random node choosen: H 7
# Random node choosen: H 8
# Random node choosen: H 5
# Random node choosen: N 55
# Random node choosen: N 56
# Node2: N 56
# Curr val2: 3
# 2 3
# max_num_edges: 2
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 42 Previous Valency: 2
# O 42 Current valency: 0
# N 56 Previous Valency: 3
# N 56 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 38
# Node1: O 47
# Curr val1: 1
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 41 Previous Valency: 2
# O 41 Current valency: 2
# O 47 Previous Valency: 1
# O 47 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 38
# Node1: H 22
# Curr val1: 1
# flag: 1
# Random node choosen: H 9
# Random node choosen: H 3
# Random node choosen: H 2
# Random node choosen: H 23
# Random node choosen: O 43
# Node2: O 43
# Curr val2: 2
# 1 2
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 22 Previous Valency: 1
# H 22 Current valency: 0
# O 43 Previous Valency: 2
# O 43 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 39
# Node1: O 47
# Curr val1: 1
# flag: 1
# Random node choosen: H 5
# Random node choosen: H 5
# Random node choosen: O 48
# Node2: O 48
# Curr val2: 1
# 1 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 47 Previous Valency: 1
# O 47 Current valency: 0
# O 48 Previous Valency: 1
# O 48 Current valency: 0
# Bonds to be formed: 50
# Number of edges: 40
# Node1: O 45
# Curr val1: 1
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# C 40 Previous Valency: 4
# C 40 Current valency: 4
# O 45 Previous Valency: 1
# O 45 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 40
# Node1: O 46
# Curr val1: 1
# flag: 1
# Random node choosen: H 26
# Random node choosen: H 19
# Random node choosen: H 19
# Random node choosen: N 49
# Random node choosen: O 48
# Random node choosen: H 4
# Random node choosen: N 54
# Node2: N 54
# Curr val2: 2
# 1 2
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 46 Previous Valency: 1
# O 46 Current valency: 0
# N 54 Previous Valency: 2
# N 54 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 41
# Node1: O 43
# Curr val1: 1
# flag: 0
# Random node choosen: H 32
# Random node choosen: H 26
# Random node choosen: C 35
# Node2: C 35
# Curr val2: 1
# 1 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# C 35 Previous Valency: 1
# C 35 Current valency: 0
# O 43 Previous Valency: 1
# O 43 Current valency: 0
# Bonds to be formed: 50
# Number of edges: 42
# Node1: O 44
# Curr val1: 1
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O 41 Previous Valency: 2
# O 41 Current valency: 2
# O 44 Previous Valency: 1
# O 44 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 42
# Node1: O 45
# Curr val1: 1
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# C 37 Previous Valency: 3
# C 37 Current valency: 3
# O 45 Previous Valency: 1
# O 45 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 42
# Node1: N 54
# Curr val1: 1
# flag: 1
# Random node choosen: H 16
# Random node choosen: N 50
# Random node choosen: H 26
# Random node choosen: N 54
# Node2: N 54
# Curr val2: 1
# 1 1
# max_num_edges: 1
# Random node choosen: H 17
# Random node choosen: H 17
# Random node choosen: C 39
# Node2: C 39
# Curr val2: 3
# 1 3
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# C 39 Previous Valency: 3
# C 39 Current valency: 2
# N 54 Previous Valency: 1
# N 54
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# N 54 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 44
# Node1: C 40
# Curr val1: 4
# flag: 1
# Random node choosen: O 46
# Random node choosen: H 2
# Random node choosen: C 36
# Random node choosen: H 3
# Random node choosen: O 46
# Random node choosen: H 31
# Node2: H 31
# Curr val2: 1
# 4 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 31 Previous Valency: 1
# H 31 Current valency: 0
# C 40 Previous Valency: 4
# C 40 Current valency: 3
# N 54
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Bonds to be formed: 50
# Number of edges: 45
# Node1: N 56
# Curr val1: 1
# flag: 1
# flag_end: 1
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# N 53 Previous Valency: 3
# N 53 Current valency: 3
# N 54
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# N 56 Previous Valency: 1
# N 56 Current valency: 1
# Bonds to be formed: 50
# Number of edges: 45
# Node1: H 27
# Curr val1: 1
# flag: 1
# Random node choosen: H 18
# Random node choosen: O 44
# Node2: O 44
# Curr val2: 1
# 1 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 27 Previous Valency: 1
# H 27 Current valency: 0
# O 44 Previous Valency: 1
# O 44 Current valency: 0
# N 54
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Bonds to be formed: 50
# Number of edges: 46
# Node1: H 25
# Curr val1: 1
# flag: 1
# Random node choosen: H 23
# Random node choosen: H 31
# Random node choosen: O 45
# Node2: O 45
# Curr val2: 1
# 1 1
# max_num_edges: 1
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# H 25 Previous Valency: 1
# H 25 Current valency: 0
# O 45 Previous Valency: 1
# O 45 Current valency: 0
# N 54
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Bonds to be formed: 50
# Number of edges: 47
# Node1: N 53
# Curr val1: 3
# flag: 0
# Random node choosen: H 10
# Random node choosen: H 1
# Random node choosen: H 4
# Random node choosen: H 17
# Random node choosen: C 36
# Random node choosen: H 2
# Random node choosen: H 21
# Random node choosen: H 5
# Random node choosen: N 52
# Random node choosen: O 48
# Random node choosen: C 33
# Random node choosen: O 47
# Random node choosen: H 32
# Random node choosen: H 22
# Random node choosen: H 1
# Random node choosen: O 45
# Random node choosen: O 43
# Random node choosen: H 29
# Random node choosen: H 5
# Random node choosen: H 7
# Random node choosen: C 37
# Node2: C 37
# Curr val2: 3
# 3 3
# max_num_edges: 3
# flag_end: 2
# H 20
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# C 37 Previous Valency: 3
# C 37 Current valency: 0
# N 53 Previous Valency: 3
# N 53 Current valency: 0
# N 54
# 1
# ValueException occured !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-3169687696c3> in <module>
# ----> 1 V = simulated_annealing(G)
#
# <ipython-input-33-cf55d61b5453> in simulated_annealing(G)
#      48             # Generating random graphs and taking input for Gfinal (Gf)
#      49             G = generate_random_graphs_new(G, maximum_edges, probab)
# ---> 50             Gf = input_G(G)
#      51             print('Gf = %f'%Gf)
#      52             initial_diff_G = Gf - Gi
#
# <ipython-input-22-731d1b622a82> in input_G(G)
#      59             plot_fig(randomp)
#      60
# ---> 61             val = float(input('Enter G value of %s: '%list(cc[i])))
#      62             data_G[sub_G] = val # Add the new compound's data to our dictionary
#      63             G_energy += val
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     891             except KeyboardInterrupt:
#     892                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 893                 raise KeyboardInterrupt("Interrupted by user") from None
#     894             else:
#     895                 break
#
# KeyboardInterrupt: Interrupted by user

# %%
for node in G.nodes:
    if node._name == "H 20": main_node = node
    print(node._name, node._valency, nx.degree(G, node))
    
cc = nx.connected_components(G)
for i in cc:
    if main_node in i:
        for j in nx.neighbors(G, main_node):
            print(j)
        plot_fig(G.subgraph(list(i)))
# Out:
# H 1 0 1
# H 2 0 1
# H 3 0 1
# H 4 0 1
# H 5 0 1
# H 6 0 1
# H 7 0 1
# H 8 0 1
# H 9 0 1
# H 10 0 1
# H 11 0 1
# H 12 0 1
# H 13 0 1
# H 14 0 1
# H 15 0 1
# H 16 0 1
# H 17 0 1
# H 18 0 1
# H 19 0 1
# H 20 1 3
# H 21 0 1
# H 22 0 1
# H 23 0 1
# H 24 0 1
# H 25 0 1
# H 26 0 1
# H 27 0 1
# H 28 0 1
# H 29 0 1
# H 30 0 1
# H 31 0 1
# H 32 0 1
# C 33 0 4
# C 34 0 4
# C 35 0 4
# C 36 0 4
# C 37 0 4
# C 38 0 4
# C 39 2 2
# C 40 3 1
# O 41 2 0
# O 42 0 2
# O 43 0 2
# O 44 0 2
# O 45 0 2
# O 46 0 2
# O 47 0 2
# O 48 0 2
# N 49 0 3
# N 50 0 3
# N 51 0 3
# N 52 0 3
# N 53 0 3
# N 54 1 5
# N 55 0 3
# N 56 1 2
# H 20
# H 32

# %%
a = nx.connected_components(G)
a = list(a)
print(a)
N = G.subgraph(list(a[9]))
input_G(N)

# %%
# Yay! input_G works. But the order of checking nodes is slight'a screwed up. Will have to check

# %%
# NOT NEEDED 

# Loop through the atoms and components
# The following are the conditions used:
#   - Choice 1: Loop through the atoms
#   - Choice 2: Loop through the compounds
#   - Choice 3: Loop through both

# n_a = len(atoms)
# n_c = len(compounds)

# a = 0
# c = 0

# choice = r.randint(0,3)

# if choice == 0:
    # a = 2
    # i = r.randint(0,n_a-1)
    # j = r.randint(0,n_a-1)
    # print('Choosing two atoms : %s and %s'%(atoms[i],atoms[j]))
    # Gi_1 = float(input('Enter G value of %s: '%atoms[i]))
    # Gi_2 = float(input('Enter G value of %s: '%atoms[j]))
    
# elif choice == 1:
    # c = 2
    # i = r.randint(0,n_c-1)
    # j = r.randint(0,n_c-1)
    # print('Choosing two compounds: %s and %s'%(compounds[i],compounds[j]))
    # Gi_1 = float(input('Enter G value of %s: '%compounds[i]))
    # Gi_2 = float(input('Enter G value of %s: '%compounds[j]))

# elif choice == 2:
    # a = 1
    # c = 1
    # i = r.randint(0,n_a-1)
    # j = r.randint(0,n_c-1)
    # print('Choosing an atom and a compound: %s and %s'%(atoms[i],compounds[j]))
    # Gi_1 = float(input('Enter G value of %s: '%atoms[i]))
    # Gi_2 = float(input('Enter G value of %s: '%compounds[j]))

# %%
def generate_random_graphs_old(G,bonds):
    # Get the list of all nodes in the network
    nodes = list(nx.nodes(G))
    # Get connected components
    connected_components = nx.connected_components(G)
    # Get the adjacency matrix, but we won't use it here
    A = nx.adjacency_matrix(G)
    # Get the number of extra edges to be formed
    # The exponential code has been added above
    bonds -= nx.number_of_edges(G)
    
    # While the number of bonds existing < number of binds needed to be formed
    while nx.number_of_edges(G) < bonds:
        # Get a random row index
        # So, here the row index would represent an atom
        # Remember 1-32 H, 33-41 C, ...
        row = r.randint(1,55)
        # Gets the current valency of the node
        cur_val1 = (nodes[row])._valency
        
        # Until a row (i.e.) a node with >1 valence if found, keep looping
        while not(cur_val1 > 0):
            row = r.randint(1,55)
            cur_val1 = nodes[row]._valency
        # Once found, get the second node, the column in the network
        else:
            col = r.randint(0, row-1)
            cur_val2 = nodes[col]._valency
            # Until a column (i.e.) a node with >1 valence if found, keep looping
            while not(cur_val2 > 0):
                col = r.randint(0, row-1)
                cur_val2 = nodes[col]._valency
                if cur_val2 > 0:
                    # If feasible nodes are found, add edge between them
                    G.add_edge(nodes[row], nodes[col])
            # If feasible edges are found before all this looping stuf, add edge
            else:
                G.add_edge(nodes[row], nodes[col])
        
        # Update the valency of all the nodes once a bond is formed
        for i in list(nx.nodes(G)): 
            i.current_valency(G)
    
    # Finally return the graph which was found with great efforts :D
    return G

# %%
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_node_match('size', 1)
nm = iso.categorical_node_match(['color', 'size'], ['red', 2])
print(nm)

# %%
a = [1,2,3,4]
b = [3,4,1,2]
b = b.sort()
a = a.sort()
if b == a:
    print(True)
else:
    print(False)
